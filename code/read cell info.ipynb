# %%
import pandas as pd
import os


# pd.read_excel()

# %%
pth=os.path.join("..","exp data","cell setup info")
f=os.listdir(pth)
f_path=os.join(pth,f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 pth=os.path.join("..","exp data","cell setup info")
#       2 f=os.listdir(pth)
# ----> 3 f_path=os.join(pth,f)
#
# AttributeError: module 'os' has no attribute 'join'
